# %% [markdown]
# Day 1 of Python Programming

# %%
# Variable, 'min' and 'max' function

Data = [2,4,6,8,10]
print('minimum value is', min(Data))
print('maximum value is', max(Data))

# %%
# Declaring multiple variables in one line

car, model, engine = 'BMW E90', 2005, 'Turbo Inline 6'
print("This is a", car, "\nIt's a model of", model, "\nIt's engine is a", engine)

# %%
# 'Type' and 'Len' Function
Username = 'Faiz'
print(type(Username))
print(len(Username))
print(type(len(Username)))

# %%
# Data Types

String = 'Faiz'
Integar = 48
List = ["mango", 'apple', 'Banana']
Dictionary = { 'Name' : 'Faiz', 
'Age' : 16,
'Country' : 'India'}
Tuple = ('Apple', 'Mango', 'Banana')
Set = {2.4, 5, 'apple', 4+2j}
